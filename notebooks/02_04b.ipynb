# %% [markdown]
# ## Working with Missing Data in Pandas

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %% [markdown]
# ### Filling missing values using fillna(), replace() and interpolate()

# %%
data = {'names': ['steve', 'shaun', 'richard','sarah','supun', 'sandun','thisali'],
         'age': [21,25,43,22,31,20,18],
         'gender': ['Male','Male','Male','Female','Male','Male','Female'],
         'rank': [2,1,4,5,3,7,6]}

ranking_df = DataFrame(data)
ranking_df.iloc[2:5,1] = np.nan
ranking_df.iloc[3:6,3] = np.nan
ranking_df.iloc[3,:] = np.nan
ranking_df
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard   NaN    Male   4.0
# 3      NaN   NaN     NaN   NaN
# 4    supun   NaN    Male   NaN
# 5   sandun  20.0    Male   NaN
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.isnull()
# Out:
#    names    age  gender   rank
# 0  False  False   False  False
# 1  False  False   False  False
# 2  False   True   False  False
# 3   True   True    True   True
# 4  False   True   False   True
# 5  False  False   False   True
# 6  False  False   False  False

# %%
ranking_df.notnull()
# Out:
#    names    age  gender   rank
# 0   True   True    True   True
# 1   True   True    True   True
# 2   True  False    True   True
# 3  False  False   False  False
# 4   True  False    True  False
# 5   True   True    True  False
# 6   True   True    True   True

# %%
bool_series = pd.isnull(ranking_df['age'])

# %%
ranking_df['age']
# Out:
# 0    21.0
# 1    25.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5    20.0
# 6    18.0
# Name: age, dtype: float64

# %%
ranking_df[bool_series]
# Out:
#      names  age gender  rank
# 2  richard  NaN   Male   4.0
# 3      NaN  NaN    NaN   NaN
# 4    supun  NaN   Male   NaN

# %%
ranking_df.fillna(0)
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard   0.0    Male   4.0
# 3        0   0.0       0   0.0
# 4    supun   0.0    Male   0.0
# 5   sandun  20.0    Male   0.0
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.fillna(method='pad')
# Out:
# /tmp/ipykernel_35133/2647120121.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='pad')
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard  25.0    Male   4.0
# 3  richard  25.0    Male   4.0
# 4    supun  25.0    Male   4.0
# 5   sandun  20.0    Male   4.0
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.fillna(method='bfill')
# Out:
# /tmp/ipykernel_35133/3253257716.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='bfill')
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard  20.0    Male   4.0
# 3    supun  20.0    Male   6.0
# 4    supun  20.0    Male   6.0
# 5   sandun  20.0    Male   6.0
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.interpolate(method='linear')
# Out:
# /tmp/ipykernel_35133/4007689601.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ranking_df.interpolate(method='linear')
#      names    age  gender  rank
# 0    steve  21.00    Male   2.0
# 1    shaun  25.00    Male   1.0
# 2  richard  23.75    Male   4.0
# 3      NaN  22.50     NaN   4.5
# 4    supun  21.25    Male   5.0
# 5   sandun  20.00    Male   5.5
# 6  thisali  18.00  Female   6.0

# %%
ranking_df.interpolate(method='linear')
# Out:
# /tmp/ipykernel_35133/4007689601.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ranking_df.interpolate(method='linear')
#      names    age  gender  rank
# 0    steve  21.00    Male   2.0
# 1    shaun  25.00    Male   1.0
# 2  richard  23.75    Male   4.0
# 3      NaN  22.50     NaN   4.5
# 4    supun  21.25    Male   5.0
# 5   sandun  20.00    Male   5.5
# 6  thisali  18.00  Female   6.0

# %%
ranking_df.interpolate(method='linear')
# Out:
# /tmp/ipykernel_35133/4007689601.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ranking_df.interpolate(method='linear')
#      names    age  gender  rank
# 0    steve  21.00    Male   2.0
# 1    shaun  25.00    Male   1.0
# 2  richard  23.75    Male   4.0
# 3      NaN  22.50     NaN   4.5
# 4    supun  21.25    Male   5.0
# 5   sandun  20.00    Male   5.5
# 6  thisali  18.00  Female   6.0

# %%
ranking_df
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard   NaN    Male   4.0
# 3      NaN   NaN     NaN   NaN
# 4    supun   NaN    Male   NaN
# 5   sandun  20.0    Male   NaN
# 6  thisali  18.0  Female   6.0

# %%
ranking_df
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard   NaN    Male   4.0
# 3      NaN   NaN     NaN   NaN
# 4    supun   NaN    Male   NaN
# 5   sandun  20.0    Male   NaN
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.dropna()
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 6  thisali  18.0  Female   6.0

# %%
mask = ranking_df['age'] > 20
ranking_df[mask]
# Out:
#    names   age gender  rank
# 0  steve  21.0   Male   2.0
# 1  shaun  25.0   Male   1.0

# %%
ranking_df.iloc[2:5,1:3]
# Out:
#    age gender
# 2  NaN   Male
# 3  NaN    NaN
# 4  NaN   Male

# %%
ranking_df.dropna(how='all')
# Out:
#      names   age  gender  rank
# 0    steve  21.0    Male   2.0
# 1    shaun  25.0    Male   1.0
# 2  richard   NaN    Male   4.0
# 4    supun   NaN    Male   NaN
# 5   sandun  20.0    Male   NaN
# 6  thisali  18.0  Female   6.0

# %%
ranking_df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
ranking_df.dropna(axis=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35133/3724080927.py in ?()
# ----> 1 ranking_df.dropna(axis=2)
#
# ~/.local/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6654         if isinstance(axis, (tuple, list)):
#    6655             # GH20987
#    6656             raise TypeError("supplying multiple axes to axis is no longer supported.")
#    6657
# -> 6658         axis = self._get_axis_number(axis)
#    6659         agg_axis = 1 - axis
#    6660
#    6661         agg_obj = self
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in ?(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 2 for object type DataFrame
