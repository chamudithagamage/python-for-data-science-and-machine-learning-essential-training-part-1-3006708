# %% [markdown]
# ## Creating labels and annotations

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 12,4
sb.set_style('whitegrid')

# %% [markdown]
# ### Labeling plot features
# #### The functional method

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)
plt.xlabel('your x axis label')
plt.ylabel('your y axis label')
# Out:
# Text(0, 0.5, 'your y axis label')

# %%
z = [1,2,3,4,0.5]
veh_type=['bicycle', 'car', 'motorbike', 'stroller','van']
plt.pie(z,labels=veh_type)
plt.show()

# %% [markdown]
# #### The object-oriented method

# %%
address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars.mpg

fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('Car names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %% [markdown]
# ### Adding a legend to your plot
# #### The functional method

# %%
plt.pie(z)
plt.legend(veh_type,loc='best')
plt.show()

# %% [markdown]
# #### The object-oriented method

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('Car names')
ax.set_ylabel('miles/gal')

ax.legend(loc='best')

# %% [markdown]
# ### Annotating your plot

# %%
mpg.max()
# Out:
# np.float64(33.9)

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])

mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names,rotation=60, fontsize='medium')
ax.set_title('Miles Per Gallon of Cars in mtcars')

ax.set_xlabel('Car names')
ax.set_ylabel('miles/gal')

ax.set_ylim([0,45])

ax.annotate('Toyota Corolla', xy=(19,33.9), xytext=(21,35), arrowprops=dict(facecolor='black', shrink=0.1))

ax.legend(loc='best')
